# %%
import numpy as np

# Get the interactive Tools for Matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.decomposition import PCA

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
glove_file = datapath('/Users/xiaomo_liu/Work/Research/Deep Learning/NLP/GloVe/glove.6B.100d.txt')
word2vec_glove_file = get_tmpfile("/Users/xiaomo_liu/Work/Research/Deep Learning/NLP/GloVe/glove.6B.100d.word2vec.txt")
glove2word2vec(glove_file, word2vec_glove_file)
# Out:
# (400000, 100)

# %%
model = KeyedVectors.load_word2vec_format(word2vec_glove_file)

# %%
model.most_similar('obama')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('barack', 0.937216579914093),
#  ('bush', 0.927285373210907),
#  ('clinton', 0.8960003852844238),
#  ('mccain', 0.8875633478164673),
#  ('gore', 0.8000321388244629),
#  ('hillary', 0.7933663129806519),
#  ('dole', 0.7851964235305786),
#  ('rodham', 0.751889705657959),
#  ('romney', 0.7488929629325867),
#  ('kerry', 0.7472623586654663)]

# %%
model.most_similar(negative='banana')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('keyrates', 0.7173938751220703),
#  ('sungrebe', 0.7119239568710327),
#  ('þórður', 0.7067720890045166),
#  ('zety', 0.7056615352630615),
#  ('23aou94', 0.6959497928619385),
#  ('___________________________________________________________',
#   0.694915235042572),
#  ('elymians', 0.6945434212684631),
#  ('camarina', 0.6927202939987183),
#  ('ryryryryryry', 0.6905653476715088),
#  ('maurilio', 0.6865653395652771)]

# %%
model.most_similar(positive=['woman', 'king'], negative=['man'])
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('queen', 0.7698541283607483),
#  ('monarch', 0.6843380928039551),
#  ('throne', 0.6755735874176025),
#  ('daughter', 0.6594556570053101),
#  ('princess', 0.6520534753799438),
#  ('prince', 0.6517034769058228),
#  ('elizabeth', 0.6464517712593079),
#  ('mother', 0.6311717629432678),
#  ('emperor', 0.6106470823287964),
#  ('wife', 0.6098655462265015)]

# %%
def analogy(x1, x2, y1):
    result = model.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy('japan', 'japanese', 'australia')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'australian'

# %%
analogy('australia', 'beer', 'france')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'champagne'

# %%
analogy('obama', 'clinton', 'reagan')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'nixon'

# %%
analogy('tall', 'tallest', 'long')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'longest'

# %%
analogy('good', 'fantastic', 'bad')
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'terrible'

# %%
print(model.doesnt_match("breakfast cereal dinner lunch".split()))
# Out:
# cereal
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/models/keyedvectors.py:893: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /anaconda2/envs/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]
        
    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]
    
    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)

# %%
display_pca_scatterplot(model, 
                        ['coffee', 'tea', 'beer', 'wine', 'brandy', 'rum', 'champagne', 'water',
                         'spaghetti', 'borscht', 'hamburger', 'pizza', 'falafel', 'sushi', 'meatballs',
                         'dog', 'horse', 'cat', 'monkey', 'parrot', 'koala', 'lizard',
                         'frog', 'toad', 'monkey', 'ape', 'kangaroo', 'wombat', 'wolf',
                         'france', 'germany', 'hungary', 'luxembourg', 'australia', 'fiji', 'china',
                         'homework', 'assignment', 'problem', 'exam', 'test', 'class',
                         'school', 'college', 'university', 'institute'])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
display_pca_scatterplot(model, sample=20)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
X = np.array([[-1, -1, -8], [-2, -1, 1], [-3, -2, 5], [1, 1, -4], [2, 1, 0], [3, 2, 1]])

# %%
pca = PCA(n_components=3)
pca.fit(X).transform(X)
# Out:
# array([[ 6.83448076e+00, -2.57133500e+00, -1.98040925e-01],
#        [-2.18405274e+00, -1.88023983e+00,  2.36057074e-01],
#        [-6.35608367e+00, -2.57241973e+00, -1.03125589e-01],
#        [ 3.35064946e+00,  8.32415359e-01,  3.28649698e-01],
#        [-4.44367965e-01,  2.32899328e+00, -2.69762564e-01],
#        [-1.20062585e+00,  3.86258592e+00,  6.22230627e-03]])

# %%
pca.fit_transform(X)
# Out:
# array([[ 6.83448076e+00, -2.57133500e+00, -1.98040925e-01],
#        [-2.18405274e+00, -1.88023983e+00,  2.36057074e-01],
#        [-6.35608367e+00, -2.57241973e+00, -1.03125589e-01],
#        [ 3.35064946e+00,  8.32415359e-01,  3.28649698e-01],
#        [-4.44367965e-01,  2.32899328e+00, -2.69762564e-01],
#        [-1.20062585e+00,  3.86258592e+00,  6.22230627e-03]])
